# %% [markdown]
# ## Mini 2

# %% [markdown]
# Speedup for different ammounts of workers:
#
# 1 workers: 0.073s, speedup=0.91x, eff=91%
# 2 workers: 0.039s, speedup=1.70x, eff=85%
# 3 workers: 0.047s, speedup=1.40x, eff=47%
# 4 workers: 0.033s, speedup=1.98x, eff=50%
# 5 workers: 0.032s, speedup=2.05x, eff=41%
# 6 workers: 0.025s, speedup=2.64x, eff=44%
# 7 workers: 0.024s, speedup=2.71x, eff=39%
# 8 workers: 0.021s, speedup=3.20x, eff=40%
# 9 workers: 0.019s, speedup=3.41x, eff=38%
# 10 workers: 0.018s, speedup=3.70x, eff=37%
# 11 workers: 0.017s, speedup=3.91x, eff=36%
# 12 workers: 0.015s, speedup=4.38x, eff=36%
# 13 workers: 0.015s, speedup=4.45x, eff=34%
# 14 workers: 0.014s, speedup=4.69x, eff=33%
# 15 workers: 0.013s, speedup=4.96x, eff=33%
# 16 workers: 0.013s, speedup=4.96x, eff=31%
# 17 workers: 0.013s, speedup=5.20x, eff=31%
# 18 workers: 0.012s, speedup=5.61x, eff=31%
# 19 workers: 0.012s, speedup=5.53x, eff=29%
# 20 workers: 0.011s, speedup=5.87x, eff=29%
# 21 workers: 0.012s, speedup=5.52x, eff=26%
# 22 workers: 0.012s, speedup=5.39x, eff=25%
# 23 workers: 0.012s, speedup=5.68x, eff=25%
# 24 workers: 0.012s, speedup=5.43x, eff=23%
# 25 workers: 0.012s, speedup=5.52x, eff=22%
# 26 workers: 0.011s, speedup=5.83x, eff=22%
# 27 workers: 0.011s, speedup=6.01x, eff=22%
# 28 workers: 0.012s, speedup=5.45x, eff=19%

# %% [markdown]
# dask:
# Dask local (n_chunks=32): 0.102 s
#
# Dask different chunk sizes:
# Dask local (n_chunks=1): 0.091 s
# Dask local (n_chunks=2): 0.074 s
# Dask local (n_chunks=3): 0.072 s
# Dask local (n_chunks=4): 0.051 s
# Dask local (n_chunks=5): 0.060 s
# Dask local (n_chunks=6): 0.051 s
# Dask local (n_chunks=7): 0.065 s
# Dask local (n_chunks=8): 0.050 s
# Dask local (n_chunks=9): 0.054 s
# Dask local (n_chunks=10): 0.080 s
# Dask local (n_chunks=11): 0.053 s
# Dask local (n_chunks=12): 0.054 s
# Dask local (n_chunks=13): 0.073 s
# Dask local (n_chunks=14): 0.108 s
# Dask local (n_chunks=15): 0.076 s
# Dask local (n_chunks=16): 0.108 s
# Dask local (n_chunks=17): 0.057 s
# Dask local (n_chunks=18): 0.068 s
# Dask local (n_chunks=19): 0.065 s
# Dask local (n_chunks=20): 0.064 s
# Dask local (n_chunks=21): 0.065 s
# Dask local (n_chunks=22): 0.066 s
# Dask local (n_chunks=23): 0.085 s
# Dask local (n_chunks=24): 0.083 s
# Dask local (n_chunks=25): 0.086 s
# Dask local (n_chunks=26): 0.127 s
# Dask local (n_chunks=27): 0.096 s
# Dask local (n_chunks=28): 0.105 s
# Dask local (n_chunks=29): 0.095 s
# Dask local (n_chunks=30): 0.095 s
# Dask local (n_chunks=31): 0.115 s
# Dask local (n_chunks=32): 0.111 s
# Best chunk_size: 8 with time 0.050 s
