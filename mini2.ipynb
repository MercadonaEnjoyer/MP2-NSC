# %% [markdown]
# ## Mini 2

# %% [markdown]
# Speedup for different ammounts of workers for parallel:
# ```
# 1 workers: 0.073s, speedup=0.91x, eff=91%
# 2 workers: 0.039s, speedup=1.70x, eff=85%
# 3 workers: 0.047s, speedup=1.40x, eff=47%
# 4 workers: 0.033s, speedup=1.98x, eff=50%
# 5 workers: 0.032s, speedup=2.05x, eff=41%
# 6 workers: 0.025s, speedup=2.64x, eff=44%
# 7 workers: 0.024s, speedup=2.71x, eff=39%
# 8 workers: 0.021s, speedup=3.20x, eff=40%
# 9 workers: 0.019s, speedup=3.41x, eff=38%
# 10 workers: 0.018s, speedup=3.70x, eff=37%
# 11 workers: 0.017s, speedup=3.91x, eff=36%
# 12 workers: 0.015s, speedup=4.38x, eff=36%
# 13 workers: 0.015s, speedup=4.45x, eff=34%
# 14 workers: 0.014s, speedup=4.69x, eff=33%
# 15 workers: 0.013s, speedup=4.96x, eff=33%
# 16 workers: 0.013s, speedup=4.96x, eff=31%
# 17 workers: 0.013s, speedup=5.20x, eff=31%
# 18 workers: 0.012s, speedup=5.61x, eff=31%
# 19 workers: 0.012s, speedup=5.53x, eff=29%
# 20 workers: 0.011s, speedup=5.87x, eff=29%
# 21 workers: 0.012s, speedup=5.52x, eff=26%
# 22 workers: 0.012s, speedup=5.39x, eff=25%
# 23 workers: 0.012s, speedup=5.68x, eff=25%
# 24 workers: 0.012s, speedup=5.43x, eff=23%
# 25 workers: 0.012s, speedup=5.52x, eff=22%
# 26 workers: 0.011s, speedup=5.83x, eff=22%
# 27 workers: 0.011s, speedup=6.01x, eff=22%
# 28 workers: 0.012s, speedup=5.45x, eff=19%
# ```
# Amdahl's law can easyly be percieved in the values as they plateau as workers go up. Each aditional worker contributes less to the task also dropping the efficiency till adding more workers is just redundant.
#
# Table with rundown of different chunks:
# ```
# n_chunks | time (s) | vs 1x  | speedup | LIF
# -------------------------------------------------------
#        1 |    0.065 |   1.00 |    1.00 |    7.000
#        2 |    0.035 |   0.54 |    1.85 |    3.327
#        3 |    0.041 |   0.63 |    1.59 |    4.040
#        4 |    0.029 |   0.45 |    2.20 |    2.633
#        5 |    0.028 |   0.43 |    2.32 |    2.449
#        6 |    0.022 |   0.34 |    2.95 |    1.709
#        7 |    0.022 |   0.33 |    3.00 |    1.665
#        8 |    0.018 |   0.28 |    3.53 |    1.265
#        9 |    0.017 |   0.27 |    3.74 |    1.141
#       10 |    0.021 |   0.33 |    3.05 |    1.627
#       11 |    0.015 |   0.24 |    4.20 |    0.907
#       12 |    0.015 |   0.23 |    4.43 |    0.804
#       13 |    0.013 |   0.21 |    4.82 |    0.661
#       14 |    0.012 |   0.19 |    5.28 |    0.514
#       15 |    0.012 |   0.19 |    5.19 |    0.541
#       16 |    0.013 |   0.20 |    5.12 |    0.561
#       17 |    0.014 |   0.21 |    4.71 |    0.698
#       18 |    0.013 |   0.19 |    5.17 |    0.547
#       19 |    0.013 |   0.21 |    4.82 |    0.660
#       20 |    0.014 |   0.21 |    4.70 |    0.702
#       21 |    0.018 |   0.28 |    3.60 |    1.220
#       22 |    0.014 |   0.21 |    4.70 |    0.704
#       23 |    0.019 |   0.29 |    3.44 |    1.327
#       24 |    0.013 |   0.20 |    4.88 |    0.639
#       25 |    0.013 |   0.20 |    5.03 |    0.590
#       26 |    0.013 |   0.20 |    5.05 |    0.583
#       27 |    0.013 |   0.20 |    5.02 |    0.594
#       28 |    0.014 |   0.21 |    4.72 |    0.694
#       29 |    0.013 |   0.21 |    4.85 |    0.651
#       30 |    0.015 |   0.22 |    4.47 |    0.790
#       31 |    0.014 |   0.21 |    4.80 |    0.667
#       32 |    0.015 |   0.23 |    4.41 |    0.813
#
# n_chunks optimal : 14
# t_min            : 0.012 s
# LIF_min          : 0.514
# ```
# It can be observed how the time for 1 task is equal to the time expected from the execution of the code using only njit, it then reaches the best performance arround 12 workers achieving better load balancing as some areas are more complex than others. Overhead is introduced with further chunks however, seeing a small decline as workload becomes too little.

# %% [markdown]
# Dask is a great tool for cluster scalability, it does however struggle with lower workloads as overhead dominates, it basically trades speed for higher scheduling power and distribution.
#
# Dask local (n_chunks=32): 0.102 s
# ```
# n_chunks | time (s) | vs 1x  | speedup | LIF
# -------------------------------------------------------
#        1 |    0.082 |   1.00 |    1.00 |    7.000
#        2 |    0.059 |   0.72 |    1.39 |    4.754
#        3 |    0.066 |   0.80 |    1.25 |    5.382
#        4 |    0.063 |   0.77 |    1.31 |    5.125
#        5 |    0.054 |   0.66 |    1.52 |    4.249
#        6 |    0.053 |   0.64 |    1.56 |    4.132
#        7 |    0.061 |   0.74 |    1.35 |    4.924
#        8 |    0.049 |   0.60 |    1.68 |    3.764
#        9 |    0.050 |   0.61 |    1.65 |    3.848
#       10 |    0.058 |   0.71 |    1.41 |    4.658
#       11 |    0.049 |   0.59 |    1.69 |    3.729
#       12 |    0.059 |   0.72 |    1.40 |    4.724
#       13 |    0.078 |   0.95 |    1.05 |    6.620
#       14 |    0.062 |   0.76 |    1.32 |    5.053
#       15 |    0.091 |   1.11 |    0.90 |    7.897
#       16 |    0.090 |   1.09 |    0.92 |    7.723
#       17 |    0.055 |   0.67 |    1.50 |    4.347
#       18 |    0.057 |   0.70 |    1.44 |    4.563
#       19 |    0.083 |   1.01 |    0.99 |    7.051
#       20 |    0.065 |   0.79 |    1.27 |    5.324
#       21 |    0.066 |   0.80 |    1.24 |    5.433
#       22 |    0.073 |   0.89 |    1.12 |    6.137
#       23 |    0.075 |   0.92 |    1.09 |    6.320
#       24 |    0.074 |   0.90 |    1.11 |    6.194
#       25 |    0.075 |   0.91 |    1.10 |    6.286
#       26 |    0.124 |   1.51 |    0.66 |   11.103
#       27 |    0.119 |   1.45 |    0.69 |   10.595
#       28 |    0.093 |   1.14 |    0.88 |    8.105
#       29 |    0.107 |   1.30 |    0.77 |    9.419
#       30 |    0.124 |   1.51 |    0.66 |   11.104
#       31 |    0.106 |   1.30 |    0.77 |    9.363
#       32 |    0.107 |   1.30 |    0.77 |    9.422
#
# --- Summary ---
# n_chunks optimal : 11
# t_min            : 0.049 s
# LIF_min          : 3.729
# ```
# The best parameters for dask locally at this work load seems to be arround 9 workers as load has not yet become too little per chunk and workers do not find themselves ideling due to too litle chunks, dask works best when chunks are large enough for computation to dominate the scheduling without too much overhead.

# %% [markdown]
# Speedup table:
# ```
# Impl      | time (s) | speedup
# -------------------------------------------------------
# Naive     |  10.545  |   1x
# Numpy     |  1.031   |   10.2x
# Numba     |  0.062   |   169x
# Parallel  |  0.012   |   958x
# Dask      |  0.050   |   195x
#
# s = -0.137
# ```

# %% [markdown]
# N = 4096 max_iter = 100
# 1 Worker:
# ```
# n_chunks | time (s) | vs 1x | speedup | LIF
# -------------------------------------------------------
#        1 |    1.304 |   1.00 |    1.00 |    7.000
#        2 |    0.721 |   0.55 |    1.81 |    3.421
#        3 |    1.116 |   0.86 |    1.17 |    5.846
#        4 |    0.699 |   0.54 |    1.86 |    3.290
#        5 |    0.749 |   0.57 |    1.74 |    3.596
#        6 |    0.836 |   0.64 |    1.56 |    4.132
#        7 |    0.828 |   0.63 |    1.58 |    4.077
#        8 |    0.761 |   0.58 |    1.71 |    3.667
#        9 |    0.801 |   0.61 |    1.63 |    3.912
#       10 |    0.746 |   0.57 |    1.75 |    3.577
#       11 |    0.846 |   0.65 |    1.54 |    4.189
#       12 |    0.744 |   0.57 |    1.75 |    3.561
#       13 |    0.774 |   0.59 |    1.68 |    3.751
#       14 |    0.775 |   0.59 |    1.68 |    3.753
#       15 |    0.735 |   0.56 |    1.77 |    3.510
#       16 |    0.783 |   0.60 |    1.66 |    3.805
#       17 |    0.800 |   0.61 |    1.63 |    3.905
#       18 |    0.764 |   0.59 |    1.71 |    3.690
#       19 |    0.763 |   0.58 |    1.71 |    3.679
#       20 |    0.798 |   0.61 |    1.63 |    3.895
#       21 |    0.767 |   0.59 |    1.70 |    3.708
#       22 |    0.742 |   0.57 |    1.76 |    3.551
#       23 |    0.738 |   0.57 |    1.77 |    3.530
#       24 |    0.763 |   0.59 |    1.71 |    3.683
#       25 |    0.740 |   0.57 |    1.76 |    3.542
#       26 |    0.765 |   0.59 |    1.70 |    3.692
#       27 |    0.737 |   0.57 |    1.77 |    3.523
#       28 |    0.793 |   0.61 |    1.64 |    3.865
#       29 |    0.751 |   0.58 |    1.74 |    3.606
#       30 |    0.725 |   0.56 |    1.80 |    3.445
#       31 |    0.773 |   0.59 |    1.69 |    3.744
#       32 |    0.751 |   0.58 |    1.74 |    3.605
#
# --- Summary ---
# n_chunks optimal : 4
# t_min            : 0.699 s
# LIF_min          : 3.290
# ```
# 2 workers:
# ```
# n_chunks | time (s) | vs 1x | speedup | LIF
# -------------------------------------------------------
#        1 |    1.313 |   1.00 |    1.00 |    7.000
#        2 |    4.991 |   3.80 |    0.26 |   29.409
#        3 |    6.660 |   5.07 |    0.20 |   39.577
#        4 |    4.406 |   3.36 |    0.30 |   25.846
#        5 |    4.411 |   3.36 |    0.30 |   25.872
#        6 |    3.377 |   2.57 |    0.39 |   19.574
#        7 |    3.332 |   2.54 |    0.39 |   19.303
#        8 |    3.103 |   2.36 |    0.42 |   17.904
#        9 |    3.892 |   2.96 |    0.34 |   22.712
#       10 |    2.778 |   2.12 |    0.47 |   15.925
#       11 |    2.342 |   1.78 |    0.56 |   13.270
#       12 |    2.265 |   1.72 |    0.58 |   12.798
#       13 |    3.178 |   2.42 |    0.41 |   18.364
#       14 |    1.664 |   1.27 |    0.79 |    9.137
#       15 |    2.339 |   1.78 |    0.56 |   13.253
#       16 |    1.664 |   1.27 |    0.79 |    9.138
#       17 |    2.291 |   1.74 |    0.57 |   12.956
#       18 |    1.986 |   1.51 |    0.66 |   11.099
#       19 |    1.287 |   0.98 |    1.02 |    6.843
#       20 |    1.559 |   1.19 |    0.84 |    8.498
#       21 |    1.815 |   1.38 |    0.72 |   10.055
#       22 |    1.605 |   1.22 |    0.82 |    8.781
#       23 |    1.985 |   1.51 |    0.66 |   11.096
#       24 |    1.314 |   1.00 |    1.00 |    7.005
#       25 |    1.434 |   1.09 |    0.92 |    7.736
#       26 |    1.379 |   1.05 |    0.95 |    7.404
#       27 |    1.823 |   1.39 |    0.72 |   10.105
#       28 |    1.007 |   0.77 |    1.30 |    5.136
#       29 |    1.434 |   1.09 |    0.92 |    7.735
#       30 |    1.188 |   0.90 |    1.11 |    6.239
#       31 |    1.292 |   0.98 |    1.02 |    6.869
#       32 |    1.393 |   1.06 |    0.94 |    7.488
#
# --- Summary ---
# n_chunks optimal : 28
# t_min            : 1.007 s
# LIF_min          : 5.136
# ```
# Even with a higher resolution the work seems to be too low to be worthwhile more than one extra worker on the dask cluster, this is due to the overhead and chunk sizes which in the second one seem to even deteriorate at the begining. When using little chunks worker utilization was lower but did not have any idle time, on the contrary, with small chunk sizes it clearly had downtime while other workers were waiting for strugglers.
# ```
# Impl      | time (s) | speedup
# -------------------------------------------------------
# Numba     |  0.977   |   1x
# Parallel  |  0.179   |   5.46x
# Cluster   |  0.699   |   1.397x
# ```
# The speedup from the cluster is not good enough compared to the parallel execution as the values are still to small to make the cluster use worth while due to overhead.
